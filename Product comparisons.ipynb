# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %matplotlib inline

# %%
swissDF  = pd.read_csv("swiss_reviews.csv")

# %% [markdown]
# One of the first thing we'll need to do is transform the categories, which are a string right now, into a list of string.

# %%
def transformToList(x):
    newList=[]
    for i in range(1, len(x)):
        if i%2 != 0 :
            newList.append(x[i])
    return newList


swissDF['categories'] = swissDF['categories'].apply(lambda x: x.split("'"))
swissDF['categories'] = swissDF['categories'].apply(lambda x : transformToList(x))

# %%
swissDF.drop('Unnamed: 0', axis=1, inplace=True)
swissDF.head()
# Out:
#          asin helpful  overall  \
# 0  B000R9AAJA  [0, 0]      5.0
# 1  B000R9AAJA  [1, 1]      5.0
# 2  B000R9AAJA  [1, 1]      5.0
# 3  B000R9AAJA  [1, 1]      5.0
# 4  B000R9AAJA  [1, 1]      5.0
#
#                                           reviewText   reviewTime  \
# 0  Speakers are loud and clear. They work great! ...  11 22, 2012
# 1  These I bought for my co-worker who always bor...   02 3, 2014
# 2  I bought these speakers for a friend's birthda...   02 2, 2013
# 3  My brother bought this speaker set for me back...  10 20, 2012
# 4  I have had these for a while and they work lik...  01 31, 2013
#
#               reviewerID        reviewerName                  summary  \
# 0   A0023922YYT81KP1CWU4       Steven Caruso                   Great!
# 1  A034570920WVP7XFWHZ5I              Olyvia       Co-Worker is happy
# 2         A100FXXJZMM6PI          Phillip Ly  Logitech S-120 Speakers
# 3         A10636NGTJRUHN            sande276                   Great!
# 4         A1071EF3JDBGI0  R. Lorente "Picky"               EXCELLENT!
#
#    unixReviewTime     brand  \
# 0      1353542400  Logitech
# 1      1391385600  Logitech
# 2      1359763200  Logitech
# 3      1350691200  Logitech
# 4      1359590400  Logitech
#
#                                           categories  year  sentiment
# 0  [Electronics, Computers & Accessories, Cables ...  2012     0.9476
# 1  [Electronics, Computers & Accessories, Cables ...  2014     0.9755
# 2  [Electronics, Computers & Accessories, Cables ...  2013     0.8867
# 3  [Electronics, Computers & Accessories, Cables ...  2012     0.9463
# 4  [Electronics, Computers & Accessories, Cables ...  2013     0.8528

# %% [markdown]
# We'll first look at the overall ratings, all categories mixed together

# %%
swissDF.overall.value_counts().sort_index().plot.bar()
swissDF.overall.describe()
# Out:
# count    289878.000000
# mean          4.195468
# std           1.234766
# min           1.000000
# 25%           4.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000
# Name: overall, dtype: float64

# %% [markdown]
# The ratings are pretty high, but as we have determined before this is also the case for international products. So basing our observations on raw evaluations isn't enough, we'll try to separate them by categories and perform sentiment analysis

# %%
swissDF['year'] = swissDF['reviewTime'].astype(str)
swissDF['year'] = swissDF['year'].apply(lambda x: x[-4:])

# %%
yearGroup =swissDF.groupby(['year'])
yearGroup['overall'].agg(['count', 'mean'])
# Out:
#        count      mean
# year
# 2000      12  4.416667
# 2001      49  3.918367
# 2002      70  3.942857
# 2003     205  4.136585
# 2004     307  3.491857
# 2005     826  3.984262
# 2006    1893  4.078711
# 2007    5514  4.273486
# 2008    7366  4.250068
# 2009   10814  4.258461
# 2010   15425  4.173160
# 2011   26518  4.160570
# 2012   43383  4.123343
# 2013  102387  4.243039
# 2014   75109  4.177715

# %% [markdown]
# The mean seems pretty consistent. with a few exceptions like 2004 which is probably due to a very inpopular product released back then. It also seems like the number of reviews is increasing exponentially.

# %%
yearGroup['overall'].count().plot.bar()

# %% [markdown]
# 2014 might seem smaller than 2013, but this data was collected in July 2014 which explains it.

# %% [markdown]
# We will now look at the dsitribution of reviews among swiss brands. Because some of them are much more popular than others (logitech being the most popular one) we will plot it using a logarithmic scale

# %%
swissDF.groupby(['brand'])['brand'].count().sort_values(ascending=True).plot.barh(log=True, figsize=(6, 10))

# %%
brandScore = swissDF.groupby(['brand', 'overall'])['brand']
brandScore = brandScore.count().unstack('overall')
brandScore.div(brandScore.sum(1), 0).sort_values(by=brandScore.keys()[0], ascending=False).plot(kind='barh', stacked=True, figsize=(6,10))
#problem here, the ratings are also put on a log scale so it seems like there are too many 1s. We could try to fix it or replace
#by piecharts

# %% [markdown]
# We will now group the reviews by category

# %%
categoriesCount = pd.DataFrame(swissDF['categories'].tolist()).stack().value_counts()
categoriesCount.head()
# Out:
# Electronics                  218203
# Computers & Accessories      116378
# Cables & Accessories          94113
# GPS & Navigation              75883
# Clothing, Shoes & Jewelry     45919
# dtype: int64

# %% [markdown]
# Let's focus on the most reviewed categories

# %%
categoriesCount = categoriesCount.head(50)
categoriesCount.sort_values(inplace=False, ascending=True).plot.barh(figsize=(5,15))

# %% [markdown]
# We will now take a look at how well rated each of these categories are

# %%
categoriesCount.keys()
# Out:
# Index(['Electronics', 'Computers & Accessories', 'Cables & Accessories',
#        'GPS & Navigation', 'Clothing, Shoes & Jewelry', 'Vehicle GPS', 'Mice',
#        'Sports & Handheld GPS', 'Sports & Outdoors', 'Accessories',
#        'Trucking GPS', 'Keyboards', 'Computer Speakers',
#        'Accessories & Supplies', 'Audio & Video Accessories',
#        'Running GPS Units', 'Remote Controls', 'Outdoor Gear',
#        'Camping & Hiking', 'Knives & Tools', 'GPS System Accessories',
#        'TV Remote Controls', 'Folding Knives', 'Handheld GPS Units',
#        'Video Games', 'PC', 'Keyboard & Mouse Combos', 'Cases', 'Watches',
#        'Wrist Watches', 'Home & Kitchen', 'Kitchen & Dining', 'Men',
#        'Input Devices', 'Kitchen Knives & Cutlery Accessories',
#        'Touch Screen Tablet Accessories', 'Portable Audio & Video',
#        'Headsets & Microphones', 'MP3 Players & Accessories',
#        'MP3 Player Accessories', 'Cases & Sleeves', 'Vehicle Mounts',
#        'Webcams', 'New Arrivals', 'Speaker Systems',
#        'Laptop & Netbook Computer Accessories', 'PC Headsets',
#        'Available for International Shipping',
#        'Jewelry: International Shipping Available', 'Electronics & Gadgets'],
#       dtype='object')

# %% [markdown]
# To find the entries that contain one category, the code to use looks like this

# %%
swissDF.categories.apply(lambda x: ' '.join(x)).str.contains('Electronics').head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: categories, dtype: bool

# %%
flat = swissDF.categories.apply(lambda x: ' '.join(x)).str
res = categoriesCount.keys().to_series().map(lambda c: swissDF[flat.contains(c)].overall.mean())

# %%
res = res.reset_index(drop=False)

# %%
res.columns = ['category', 'mean']

# %%
res = res.set_index(['category'])
res.head()
# Out:
#                                mean
# category
# Electronics                4.151909
# Computers & Accessories    4.237529
# Cables & Accessories       4.240466
# GPS & Navigation           4.077727
# Clothing, Shoes & Jewelry  4.236315

# %%
res.sort_values(by='mean',ascending=True).plot.barh( figsize=(6,15))
#TODO plot international products of same category on the side + maths on correlations

# %% [markdown]
# The last thing we need to check is to see what happens if we group the reviews first by product. This will show us if for example some very popluar results are skewing the means

# %%
productGroup = swissDF.groupby(['asin'])
productFrame = pd.DataFrame(productGroup['overall'].agg(['count', 'mean']))
overallGrouped = productFrame['mean']

# %%
productFrame.count()
# Out:
# count    4718
# mean     4718
# dtype: int64

# %% [markdown]
# We can see that we have 4718 unique prodcuts in total.
# Now let's get the mean product wise

# %%
print(np.mean(productFrame['mean']))
print(np.median(productFrame['mean']))
# Out:
# 4.246266143689977
# 4.44117647059

# %% [markdown]
# Evrything looks normal, which means that we have a relatively normal distrubtion of the reviews accros the products

# %%
productFrame['asin'] = productFrame.index
productFrame['brand'] = productGroup.apply(lambda x: list(x.brand)[0])
productFrame.index = range(0, 4718)
productFrame.groupby(['brand'])['mean'].agg(['count', 'mean', 'median']).sort_values(['count'])
# Out:
#                     count      mean    median
# brand
# Ulysse Nardin           1  5.000000  5.000000
# TE Connectivity         1  1.000000  1.000000
# STMicroelectronics      1  5.000000  5.000000
# Credit Suisse           1  3.000000  3.000000
# Jaeger-LeCoultre        1  5.000000  5.000000
# Girard Perregaux        1  5.000000  5.000000
# Mila                    2  4.146718  4.146718
# IQAir                   2  4.621212  4.621212
# Expert                  2  5.000000  5.000000
# Globus                  2  1.750000  1.750000
# Hublot                  3  3.666667  5.000000
# Charriol                4  4.750000  5.000000
# Maurice Lacroix         4  3.000000  2.500000
# Hello                   4  4.016667  4.200000
# Leica Geosystems        5  4.387446  4.428571
# ABB                     6  4.833333  5.000000
# Coop                    6  3.616667  4.250000
# Geberit                 6  3.162698  3.416667
# Endura                  6  4.095238  4.285714
# Mido                    8  4.166667  5.000000
# Vitol                   8  4.039878  4.375000
# Syngenta                8  4.325971  4.636272
# Jowissa                10  4.500000  4.500000
# Bamix                  11  3.823319  4.187500
# BASF                   18  4.078423  4.833333
# Zenith                 18  4.000857  4.245445
# Longines               25  4.363000  5.000000
# Chopard                26  4.262038  4.982143
# Novartis               26  4.350308  4.348148
# Rolex                  27  4.477702  5.000000
# Alcon                  32  4.612975  4.679487
# IWC                    36  4.035648  4.354167
# Rado                   39  4.448718  5.000000
# Selecta                43  4.500720  5.000000
# Festina                49  4.528912  5.000000
# Elinchrom              71  4.303206  4.600000
# Maggi                  73  4.497801  5.000000
# Raymond Weil           88  4.413447  5.000000
# Weleda                139  4.454040  4.571429
# Pelikan               156  4.341470  4.666667
# Wenger                199  4.236735  4.357143
# TAG Heuer             211  4.235122  4.444444
# Swatch                219  4.080190  4.309091
# Tissot                311  4.274385  4.469388
# Hamilton              378  4.227877  4.500000
# Logitech              595  4.084449  4.200000
# Garmin                780  3.991383  4.031929
# Victorinox           1056  4.466100  4.666667

# %% [markdown]
# This is very nice view as it shows us which brands have the most products as well as the mean and the median review for each brand.
# In general we can say that most brands, especially the most popoluar ones, are very close to the general mean and distribtuion

# %%
import ast
helpful = []
for i in range(0, len(swissDF)):
    helpful.append(ast.literal_eval(swissDF['helpful'][i])[1] + 1)

# %%
swissDF['helpful'] = helpful
swissDF['coeff'] = swissDF['helpful'] * swissDF['overall']
productGroup = swissDF.groupby(['asin'])
productFrameWeighted = pd.DataFrame(productGroup['coeff'].agg(['count', 'sum']))
temp = pd.DataFrame(productGroup['helpful'].agg(['sum']))

# %%
productFrameWeighted['mean'] = productFrameWeighted['sum']/temp['sum']

# %%
productFrameWeighted
# Out:
#             count      sum      mean
# asin
# 9984984354     79    575.0  2.521930
# B00000ISY1      1     15.0  5.000000
# B00000JXTC      7     72.0  4.500000
# B00001U07N     11    399.0  3.325000
# B0000224UE     82   1718.0  4.521053
# B00003CLRT      3     35.0  5.000000
# B00003CM1V      2     15.0  5.000000
# B00003CW8K      1     10.0  5.000000
# B00003CW8T      1     10.0  5.000000
# B00003CWVW      1      4.0  4.000000
# B00004VUGJ    525   5434.0  3.558612
# B00004VX14     28    634.0  3.107843
# B00004VX15    259   3048.0  3.072581
# B00004VX23     20    262.0  3.011494
# B00004VX39    230   2363.0  3.854812
# B00004VX3C      4    315.0  5.000000
# B00004Y308      3     28.0  1.166667
# B00004YVAE     37    936.0  4.565854
# B00004YVAJ   1542  14843.0  4.027951
# B00004YVB0    103   2322.0  4.544031
# B00004YVB1     47   1151.0  4.961207
# B00004YVB2   1546  14862.0  4.028734
# B00004YVB3   1543  14848.0  4.028215
# B00004YVB4    144   2027.0  4.340471
# B00004YVB7      1     20.0  5.000000
# B00004YVBA    112   1861.0  4.923280
# B00004YVBB    169   1364.0  4.836879
# B00004Z0C8    111   5554.0  2.706628
# B00004Z0C9     17    459.0  2.415789
# B000052XEG     27    274.0  4.491803
# ...           ...      ...       ...
# B00J7KM5X4     11    121.0  3.184211
# B00JAZGU3C     13     54.0  4.153846
# B00JAZGUBE     11     86.0  4.777778
# B00JLA5PZ0      1      3.0  3.000000
# B00JLMRXCQ     17    280.0  3.783784
# B00JQF6F9A     20    498.0  3.364865
# B00JQF6H8Y     20    498.0  3.364865
# B00JQF6HBQ     20    498.0  3.364865
# B00JQF6HCA     20    498.0  3.364865
# B00JQF6HHU     20    498.0  3.364865
# B00JQGWQGU      1      5.0  5.000000
# B00JQGWSXQ      1      5.0  5.000000
# B00JS9WTEE      2     10.0  5.000000
# B00JUHDYSO      2     23.0  4.600000
# B00JZM7T1C      1      5.0  5.000000
# B00JZM7T2Q     12     59.0  4.214286
# B00JZM7TKI     12    159.0  4.542857
# B00JZSB7NW     13    440.0  3.235294
# B00K3EPUZ8      6     44.0  4.888889
# B00K3EPV52      2      8.0  4.000000
# B00K7J2PCA      1      5.0  5.000000
# B00KCN3IOK      1      5.0  5.000000
# B00KF7P0TO      2     10.0  5.000000
# B00KK9481I     11     75.0  4.411765
# B00KNO2JI4      1      5.0  5.000000
# B00KNO2JL6      1      5.0  5.000000
# B00KOUK1HI      4     67.0  3.526316
# B00KOUK3V2      4     67.0  3.526316
# BT008T2BGK      1      5.0  5.000000
# BT008V9J9U      2      6.0  3.000000
#
# [4718 rows x 3 columns]

# %% [markdown]
# # TEXT ANALYSIS

# %% [markdown]
# Now that we have finished working with the numerical ratings, we'll try to look for differences between Swiss and international products by basing our analysis on text.
# First we'll start with the "summary" column

# %%
from nltk.sentiment.vader import *
# Out:
# C:\Users\Luc4s\Anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
stopwords = pd.read_csv('stopwords_en.csv')

# %%
summaryBody = swissDF['summary'].apply(lambda x: x.lower())
textArray = summaryBody.values.flatten()
textString = ' '.join(textArray)
cloud = WordCloud(background_color="white", stopwords=stopwords).generate(textString)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %% [markdown]
# The code below was run to execute the sentiment analysis of the reviews, we have now commented it because the result was added to the dataframe

# %%
#analyzer = nltk.sentiment.vader.SentimentIntensityAnalyzer()

# %% [markdown]
# We will now perform sentiment analysis on the review text joined with the summary

# %%
#review_polarity = []
#for i in range (0, len(swissDF['reviewText'])):
#    review_polarity.append(analyzer.polarity_scores(' '.join([str(swissDF['reviewText'][i]), swissDF['summary'][i]]))['compound'])
#    if i % 1000 == 0:
#        print(i)

# %%
#len(review_polarity)

# %%
#swissDF['sentiment'] = review_polarity

# %%
swissDF['sentiment'].head()
# Out:
# 0    0.9476
# 1    0.9755
# 2    0.8867
# 3    0.9463
# 4    0.8528
# Name: sentiment, dtype: float64

# %%
productGroup = swissDF.groupby(['asin'])
productFrame = pd.DataFrame(productGroup['sentiment'].agg(['count', 'mean']))

# %%
print("Mean of sentiment")
print(np.mean(productFrame['mean']))
print(np.median(productFrame['mean']))
# Out:
# Mean of sentiment
# 0.6534338998560479
# 0.72615

# %%
productFrame['asin'] = productFrame.index
productFrame['brand'] = productGroup.apply(lambda x: list(x.brand)[0])
productFrame.index = range(0, 4718)
productFrame.groupby(['brand'])['mean'].agg(['count', 'mean', 'median']).sort_values(['count'], ascending=False)
# Out:
#                     count      mean    median
# brand
# Victorinox           1056  0.712119  0.779360
# Garmin                780  0.501308  0.547487
# Logitech              595  0.629216  0.688054
# Hamilton              378  0.661859  0.794742
# Tissot                311  0.712240  0.790889
# Swatch                219  0.653385  0.731450
# TAG Heuer             211  0.702715  0.774700
# Wenger                199  0.665085  0.742008
# Pelikan               156  0.706711  0.819700
# Weleda                139  0.750282  0.790100
# Raymond Weil           88  0.804590  0.905475
# Maggi                  73  0.707610  0.792600
# Elinchrom              71  0.664310  0.787200
# Festina                49  0.715183  0.888600
# Selecta                43  0.854275  0.933150
# Rado                   39  0.708419  0.920150
# IWC                    36  0.622724  0.777092
# Alcon                  32  0.581915  0.599368
# Rolex                  27  0.649686  0.708800
# Novartis               26  0.507593  0.525977
# Chopard                26  0.699011  0.873650
# Longines               25  0.713750  0.862525
# Zenith                 18  0.643855  0.655587
# BASF                   18  0.210597  0.255452
# Bamix                  11  0.749532  0.760067
# Jowissa                10  0.876590  0.932450
# Vitol                   8  0.476775  0.673001
# Mido                    8  0.578601  0.696913
# Syngenta                8  0.348636  0.312556
# ABB                     6  0.795283  0.940700
# Geberit                 6  0.348567  0.462051
# Coop                    6  0.342899  0.595750
# Endura                  6  0.549075  0.858600
# Leica Geosystems        5  0.690490  0.753345
# Hello                   4  0.538133  0.501965
# Charriol                4  0.936750  0.935600
# Maurice Lacroix         4  0.806625  0.859450
# Hublot                  3  0.726633  0.726900
# Globus                  2  0.169150  0.169150
# Expert                  2  0.830650  0.830650
# Mila                    2  0.574259  0.574259
# IQAir                   2  0.656986  0.656986
# Girard Perregaux        1  0.991400  0.991400
# Credit Suisse           1  0.709075  0.709075
# TE Connectivity         1 -0.538000 -0.538000
# Ulysse Nardin           1  0.720350  0.720350
# Jaeger-LeCoultre        1  0.930700  0.930700
# STMicroelectronics      1  0.858800  0.858800

# %%
np.corrcoef(swissDF['overall'], swissDF['sentiment'])
# Out:
# array([[ 1.        ,  0.55085136],
#        [ 0.55085136,  1.        ]])

# %% [markdown]
# The correlation is 0.55, which indicates a moderatetly high correlation between the overall rating and the review

# %%
productFrame['overallGrouped'] = overallGrouped.tolist()
A = np.vstack([productFrame['mean'].tolist(),np.ones(len(productFrame['mean'].tolist()))]).T
xarr = np.array(productFrame['mean'].tolist())
m,c = np.linalg.lstsq(A,productFrame['overallGrouped'].tolist())[0]


productFrame['regression'] = (xarr*m + c)
ax = productFrame.plot.scatter(x='mean', y='regression', color="Red")
productFrame.plot.scatter(x='mean', y='overallGrouped' ,figsize=(15,15), ax=ax)
